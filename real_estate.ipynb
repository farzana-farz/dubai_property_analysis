# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("dubai_properties.csv")
data
# Out:
#                                                  Address    Rent  Beds  Baths  \
# 0      The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                    Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2                Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3      Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                        West Yas, Yas Island, Abu Dhabi  350000     5      7
# ...                                                  ...     ...   ...    ...
# 73737             Al Huboob 1, Al Salamah, Umm Al Quwain   14000     0      1
# 73738                Umm Al Quwain Marina, Umm Al Quwain   14000     0      1
# 73739                  King Faisal Street, Umm Al Quwain   50000     3      4
# 73740                           Al Maqtaa, Umm Al Quwain   37000     1      2
# 73741                             Al Rass, Umm Al Quwain   11000     0      1
#
# ...

# %%
# set decimal points to 2
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
data
# Out:
#                                                  Address    Rent  Beds  Baths  \
# 0      The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                    Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2                Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3      Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                        West Yas, Yas Island, Abu Dhabi  350000     5      7
# ...                                                  ...     ...   ...    ...
# 73737             Al Huboob 1, Al Salamah, Umm Al Quwain   14000     0      1
# 73738                Umm Al Quwain Marina, Umm Al Quwain   14000     0      1
# 73739                  King Faisal Street, Umm Al Quwain   50000     3      4
# 73740                           Al Maqtaa, Umm Al Quwain   37000     1      2
# 73741                             Al Rass, Umm Al Quwain   11000     0      1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73742 entries, 0 to 73741
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Address                 73742 non-null  object
#  1   Rent                    73742 non-null  int64
#  2   Beds                    73742 non-null  int64
#  3   Baths                   73742 non-null  int64
#  4   Type                    73742 non-null  object
#  5   Area_in_sqft            73742 non-null  int64
#  6   Rent_per_sqft           73742 non-null  float64
#  7   Rent_category           73742 non-null  object
#  8   Frequency               73742 non-null  object
#  9   Furnishing              73742 non-null  object
#  10  Purpose                 73742 non-null  object
#  11  Posted_date             73742 non-null  object
#  12  Age_of_listing_in_days  73742 non-null  int64
#  13  Location                73742 non-null  object
# ...

# %%
data.describe()
# Out:
#              Rent     Beds    Baths  Area_in_sqft  Rent_per_sqft  \
# count    73742.00 73742.00 73742.00      73742.00       73742.00
# mean    147925.00     2.16     2.65       2054.05          88.06
# std     306965.83     1.58     1.63       3003.92          66.53
# min          0.00     0.00     1.00         74.00           0.00
# 25%      54999.00     1.00     2.00        850.00          39.98
# 50%      98000.00     2.00     2.00       1334.00          71.43
# 75%     170000.00     3.00     3.00       2130.00         118.48
# max   55000000.00    12.00    11.00     210254.00        2182.04
#
#        Age_of_listing_in_days  Latitude  Longitude
# count                73742.00  73023.00   73023.00
# mean                    74.26     24.92      55.05
# std                     72.35      0.57       0.65
# min                     11.00     15.18      43.35
# 25%                     30.00     24.49      54.61
# 50%                     52.00     25.08      55.24
# ...

# %%
# count null values
data.isnull().sum()
# Out:
# Address                     0
# Rent                        0
# Beds                        0
# Baths                       0
# Type                        0
# Area_in_sqft                0
# Rent_per_sqft               0
# Rent_category               0
# Frequency                   0
# Furnishing                  0
# Purpose                     0
# Posted_date                 0
# Age_of_listing_in_days      0
# Location                    0
# City                        0
# Latitude                  719
# Longitude                 719
# dtype: int64

# %%
# counting unique values
data.nunique()
# Out:
# Address                    4515
# Rent                       2099
# Beds                         13
# Baths                        11
# Type                          9
# Area_in_sqft               4964
# Rent_per_sqft             31328
# Rent_category                 3
# Frequency                     1
# Furnishing                    2
# Purpose                       1
# Posted_date                 544
# Age_of_listing_in_days      544
# Location                    441
# City                          8
# Latitude                    412
# Longitude                   412
# dtype: int64

# %%
#sort dataset by rent
data.sort_values(by='Rent').head(20)
# Out:
#                                                  Address  Rent  Beds  Baths  \
# 56081  Garden Homes Frond K, Garden Homes Palm Jumeir...     0     4      2
# 56080  Abu Keibal, Shoreline Apartments, Palm Jumeira...     0     3      2
# 32243  Park Gate Residence A, Park Gate Residence, Al...     0     2      2
# 35389  Serenia Residences West Wing, Serenia Residenc...     0     4      2
# 32633                      Al Barsha 3, Al Barsha, Dubai     0     1      2
# 32632                             Abu Hail, Deira, Dubai     0     5      2
# 32631  Al Barsha South 2, Al Barsha South, Al Barsha,...     0     5      2
# 56079   1 Residences, Wasl 1, Al Kifaf, Bur Dubai, Dubai     0     2      2
# 66350           Hafez House, Al Nahda (Sharjah), Sharjah     0     2      2
# 34160  Al Khudrawi, Shoreline Apartments, Palm Jumeir...     0     2      2
# 56082  Marina Residences 5, Marina Residences, Palm J...     0     2      2
# ...

# %%
#count zeros 
count_rent = data['Rent'].value_counts()[0.00]
print("rent : ",count_rent)

count_beds = data['Beds'].value_counts()[0.00]
print("bed : ",count_beds)

count_rent_sqft = data['Rent_per_sqft'].value_counts()[0.00]
print("Rent_per_sqft : ",count_rent_sqft)
# Out:
# rent :  15
# bed :  8416
# Rent_per_sqft :  15

# %%
#remove duplicates
data.drop_duplicates()
# Out:
#                                                  Address    Rent  Beds  Baths  \
# 0      The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                    Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2                Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3      Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                        West Yas, Yas Island, Abu Dhabi  350000     5      7
# ...                                                  ...     ...   ...    ...
# 73737             Al Huboob 1, Al Salamah, Umm Al Quwain   14000     0      1
# 73738                Umm Al Quwain Marina, Umm Al Quwain   14000     0      1
# 73739                  King Faisal Street, Umm Al Quwain   50000     3      4
# 73740                           Al Maqtaa, Umm Al Quwain   37000     1      2
# 73741                             Al Rass, Umm Al Quwain   11000     0      1
#
# ...

# %%
#remove cols 'Age_of_listing_in_days','Purpose','Frequency'
data=data.drop(columns=['Age_of_listing_in_days','Purpose','Frequency'])
data
# Out:
#                                                  Address    Rent  Beds  Baths  \
# 0      The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                    Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2                Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3      Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                        West Yas, Yas Island, Abu Dhabi  350000     5      7
# ...                                                  ...     ...   ...    ...
# 73737             Al Huboob 1, Al Salamah, Umm Al Quwain   14000     0      1
# 73738                Umm Al Quwain Marina, Umm Al Quwain   14000     0      1
# 73739                  King Faisal Street, Umm Al Quwain   50000     3      4
# 73740                           Al Maqtaa, Umm Al Quwain   37000     1      2
# 73741                             Al Rass, Umm Al Quwain   11000     0      1
#
# ...

# %%
#split address to 2 cols
data[['Building Name','Place']]=data['Address'].str.split(',',n=1,expand=True)
data
# Out:
#                                                  Address    Rent  Beds  Baths  \
# 0      The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                    Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2                Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3      Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                        West Yas, Yas Island, Abu Dhabi  350000     5      7
# ...                                                  ...     ...   ...    ...
# 73737             Al Huboob 1, Al Salamah, Umm Al Quwain   14000     0      1
# 73738                Umm Al Quwain Marina, Umm Al Quwain   14000     0      1
# 73739                  King Faisal Street, Umm Al Quwain   50000     3      4
# 73740                           Al Maqtaa, Umm Al Quwain   37000     1      2
# 73741                             Al Rass, Umm Al Quwain   11000     0      1
#
# ...

# %%
#remove cols 'Address','Place'
data=data.drop(columns=['Address','Place','Latitude','Longitude'])
data
# Out:
#          Rent  Beds  Baths       Type  Area_in_sqft  Rent_per_sqft  \
# 0      124000     3      4  Apartment          1785          69.47
# 1      140000     3      4  Apartment          1422          98.45
# 2       99000     2      3  Apartment          1314          75.34
# 3      220000     3      4  Penthouse          3843          57.25
# 4      350000     5      7      Villa          6860          51.02
# ...       ...   ...    ...        ...           ...            ...
# 73737   14000     0      1  Apartment           419          33.41
# 73738   14000     0      1  Apartment           500          28.00
# 73739   50000     3      4  Apartment          2000          25.00
# 73740   37000     1      2  Apartment           989          37.41
# 73741   11000     0      1  Apartment           300          36.67
#
#       Rent_category   Furnishing Posted_date              Location  \
# 0            Medium  Unfurnished  2024-03-07        Al Reem Island
# ...

# %%
# remove rows with value 0 in col Rent
data = data[data['Rent'] != 0]

data
# Out:
#          Rent  Beds  Baths       Type  Area_in_sqft  Rent_per_sqft  \
# 0      124000     3      4  Apartment          1785          69.47
# 1      140000     3      4  Apartment          1422          98.45
# 2       99000     2      3  Apartment          1314          75.34
# 3      220000     3      4  Penthouse          3843          57.25
# 4      350000     5      7      Villa          6860          51.02
# ...       ...   ...    ...        ...           ...            ...
# 73737   14000     0      1  Apartment           419          33.41
# 73738   14000     0      1  Apartment           500          28.00
# 73739   50000     3      4  Apartment          2000          25.00
# 73740   37000     1      2  Apartment           989          37.41
# 73741   11000     0      1  Apartment           300          36.67
#
#       Rent_category   Furnishing Posted_date              Location  \
# 0            Medium  Unfurnished  2024-03-07        Al Reem Island
# ...

# %%
#checking null values
data.isna().sum()
# Out:
# Rent             0
# Beds             0
# Baths            0
# Type             0
# Area_in_sqft     0
# Rent_per_sqft    0
# Rent_category    0
# Furnishing       0
# Posted_date      0
# Location         0
# City             0
# Building Name    0
# dtype: int64

# %%
df=pd.DataFrame(data)
df
# Out:
#          Rent  Beds  Baths       Type  Area_in_sqft  Rent_per_sqft  \
# 0      124000     3      4  Apartment          1785          69.47
# 1      140000     3      4  Apartment          1422          98.45
# 2       99000     2      3  Apartment          1314          75.34
# 3      220000     3      4  Penthouse          3843          57.25
# 4      350000     5      7      Villa          6860          51.02
# ...       ...   ...    ...        ...           ...            ...
# 73737   14000     0      1  Apartment           419          33.41
# 73738   14000     0      1  Apartment           500          28.00
# 73739   50000     3      4  Apartment          2000          25.00
# 73740   37000     1      2  Apartment           989          37.41
# 73741   11000     0      1  Apartment           300          36.67
#
#       Rent_category   Furnishing Posted_date              Location  \
# 0            Medium  Unfurnished  2024-03-07        Al Reem Island
# ...

# %%
#filename="property_cleaned.xlsx"
#df.to_excel(filename,index=False)

# %%
# writing to Excel
     #datatoexcel = pd.ExcelWriter('property_data.xlsx')

# write DataFrame to excel
     #df.to_excel(datatoexcel,index=False)
# Save the DataFrame as a new Excel file
file='C:\\Users\\shereef\\Desktop\\property_data.xlsx'
df.to_excel(file, index=False)

# save the excel
     #datatoexcel.close()

# %%
import seaborn as sns

# %%
sns.boxplot(y=data['Rent_per_sqft'])   # data is passing to x axis
plt.title("Box Plot")
plt.show()
